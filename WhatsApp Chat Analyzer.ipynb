# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
import functions
import re
from collections import Counter
import matplotlib.pyplot as plt
import urlextract
import emoji
from wordcloud import WordCloud
# %matplotlib inline

# %%
file = open('WhatsApp Chat with GDSC KIIT Alumni Network.txt','r',encoding='utf-8')

# %%
def generateDataFrame(file):
    data = file.read()
    data = data.replace('\u202f', ' ')
    data = data.replace('\n', ' ')
    dt_format = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s?(?:AM\s|PM\s|am\s|pm\s)?-\s'
    # print(data)
    msgs = re.split(dt_format, data)[1:]
    # print(msgs)
    date_times = re.findall(dt_format, data)
    date = []
    time = []
    for dt in date_times:
        date.append(re.search('\d{1,2}/\d{1,2}/\d{2,4}', dt).group())
        time.append(re.search('\d{1,2}:\d{2}\s?(?:AM|PM|am|pm)?', dt).group())
    users = []
    message = []
    for m in msgs:
        s = re.split('([\w\W]+?):\s', m)
        if (len(s) < 3):
            users.append("Notifications")
            message.append(s[0])
        else:
            users.append(s[1])
            message.append(s[2])
    df = pd.DataFrame(list(zip(date, time, users, message)), columns=["Date", "Time(U)", "User", "Message"])
    return df

# %%
df = generateDataFrame(file)

# %%
df.head()
# Out:
#       Date  Time(U)           User  \
# 0   6/6/22  9:16 PM  Notifications
# 1  9/14/20  8:14 PM  Notifications
# 2   6/6/22  9:16 PM  Notifications
# 3   6/6/22  9:16 PM  Notifications
# 4   6/6/22  9:18 PM  Notifications
#
#                                              Message
# 0  Messages and calls are end-to-end encrypted. N...
# 1  ~ Praddyum created group "DSC KIIT Alumni Netw...
# 2         You joined using this group's invite link
# 3  +91 87072 17791 joined using this group's invi...
# 4  +91 70776 30863 joined using this group's invi...

# %%
df.shape
# Out:
# (438, 4)

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=False)
df['Time'] = pd.to_datetime(df['Time(U)']).dt.time
df['year'] = df['Date'].apply(lambda x: int(str(x)[:4]))
df['month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['date'] = df['Date'].apply(lambda x: int(str(x)[8:10]))
df['day'] = df['Date'].apply(lambda x: x.day_name())
df['hour'] = df['Time'].apply(lambda x: int(str(x)[:2]))
df['month_name'] = df['Date'].apply(lambda x: x.month_name())
# Out:
# C:\Users\Aakash\AppData\Local\Temp\ipykernel_17716\2410288521.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=False)
# C:\Users\Aakash\AppData\Local\Temp\ipykernel_17716\2410288521.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time(U)']).dt.time

# %%
df.head()
# Out:
#         Date  Time(U)           User  \
# 0 2022-06-06  9:16 PM  Notifications
# 1 2020-09-14  8:14 PM  Notifications
# 2 2022-06-06  9:16 PM  Notifications
# 3 2022-06-06  9:16 PM  Notifications
# 4 2022-06-06  9:18 PM  Notifications
#
#                                              Message      Time  year  month  \
# 0  Messages and calls are end-to-end encrypted. N...  21:16:00  2022      6
# 1  ~ Praddyum created group "DSC KIIT Alumni Netw...  20:14:00  2020      9
# 2         You joined using this group's invite link   21:16:00  2022      6
# 3  +91 87072 17791 joined using this group's invi...  21:16:00  2022      6
# 4  +91 70776 30863 joined using this group's invi...  21:18:00  2022      6
#
#    date     day  hour month_name
# 0     6  Monday    21       June
# 1    14  Monday    20  September
# 2     6  Monday    21       June
# 3     6  Monday    21       June
# 4     6  Monday    21       June

# %%
def getStats(df):
    media = df[df['Message'] == "<Media omitted> "]
    media_cnt = media.shape[0]
    df.drop(media.index, inplace=True)
    deleted_msgs = df[df['Message'] == "This message was deleted "]
    deleted_msgs_cnt = deleted_msgs.shape[0]
    df.drop(deleted_msgs.index, inplace=True)
    temp = df[df['User'] == 'Notifications']
    df.drop(temp.index, inplace=True)
    print("h4")
    extractor = urlextract.URLExtract()
    print("h3")
    links = []
    for msg in df['Message']:
        x = extractor.find_urls(msg)
        if x:
            links.extend(x)
    links_cnt = len(links)
    word_list = []
    for msg in df['Message']:
        word_list.extend(msg.split())
    word_count = len(word_list)
    msg_count = df.shape[0]
    return df, media_cnt, deleted_msgs_cnt, links_cnt, word_count, msg_count

# %%
df, media_cnt, deleted_msgs_cnt, links_cnt, word_count, msg_count = functions.getStats(df)
# Out:
# h4
# h3

# %%
print(media_cnt, deleted_msgs_cnt, links_cnt, word_count, msg_count)
# Out:
# 22 0 22 2400 315

# %%
                x = df['User'].value_counts().head()    # counts the occurence of the each user
                name = x.index         #name of the user
                count = x.values       #number of message
                st.title("Messaging Frequency")
                st.subheader('Messaging Percentage Count of Users')
                col1, col2 = st.columns(2)
                with col1:
                    st.dataframe(round((df['User'].value_counts() / df.shape[0]) * 100, 2).reset_index().rename(
                    columns={'User': 'name', 'count': 'percent'}))
                with col2:
                    fig, ax = plt.subplots()
                    ax.bar(name, count)
                    ax.set_xlabel("Users")
                    ax.set_ylabel("Message Sent")
                    plt.xticks(rotation='vertical')
                    st.pyplot(fig)

# %%
counts = df['User'].value_counts().head()
plt.figure(figsize=(15, 7))
plt.bar(counts.index, counts.values)
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '+91 99568 76609'),
#   Text(1, 0, '+91 99339 19759'),
#   Text(2, 0, '+91 73001 16694'),
#   Text(3, 0, '+91 90073 75777'),
#   Text(4, 0, '+977 986-7234454')])

# %%
def MostCommonWords(df):
    f = open('stop_hinglish.txt')
    stop_words = f.read()
    f.close()
    words = []
    for message in df['Message']:
        for word in message.lower().split():
            if word not in stop_words:
                words.append(word)
    return pd.DataFrame(Counter(words).most_common(20))

# %%
mostcommon = MostCommonWords(df)
mostcommon
# Out:
#                   0   1
# 0   congratulations  16
# 1              kiit  11
# 2          congrats  10
# 3              make   8
# 4              tier   8
# 5              kaam   8
# 6        internship   7
# 7              meet   7
# 8         wordpress   7
# 9            campus   6
# 10          college   6
# 11             feel   5
# 12             link   5
# 13             year   5
# 14           junior   5
# 15          company   5
# 16         platform   5
# 17             life   4
# 18              day   4
# 19                🥲   4

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\aakash\appdata\local\programs\python\python311\lib\site-packages (2.10.1)

# %%
import emoji

# %%
def getEmoji(df):
    emojis = []
    for message in df['Message']:
        # checks for emojis in the messages using unicode
        emojis.extend([c for c in message if c in emoji.EMOJI_DATA])
    return pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))


dfmoji = getEmoji(df)
dfmoji
# Out:
#     0   1
# 0   🥲  10
# 1   😂  10
# 2   🏻   7
# 3   🫠   7
# 4   🙂   5
# 5   🎉   5
# 6   🥳   4
# 7   😌   4
# 8   👏   3
# 9   🙌   3
# 10  🤣   3
# 11  😎   2
# 12  😅   2
# 13  👀   2
# 14  🙃   2
# 15  🥂   2
# 16  ✨   2
# 17  🍾   2
# 18  🔥   2
# 19  💀   2
# 20  🌚   1
# 21  🌟   1
# 22  😍   1
# 23  ❤   1
# 24  😁   1
# 25  😀   1
# 26  🥹   1
# 27  🤷   1
# 28  ♂   1
# 29  🙏   1
# 30  🤟   1
# 31  🫡   1

# %%
def getMonthlyTimeline(df):

    df.columns = df.columns.str.strip()
    df = df.reset_index()
    # first group by year and then month and takes no. of messages
    timeline = df.groupby(['year', 'month']).count()['Message'].reset_index()
    time = []
    for i in range(timeline.shape[0]):
        # time list adds month and year along with the messages
        time.append(str(timeline['month'][i]) + "-" + str(timeline['year'][i]))
    timeline['time'] = time
    timeline
    return timeline

# %%
getMonthlyTimeline(df)
# Out:
#     year  month  Message     time
# 0   2022      6       22   6-2022
# 1   2022      7       40   7-2022
# 2   2022      8       58   8-2022
# 3   2022      9       21   9-2022
# 4   2022     11       21  11-2022
# 5   2023      1        3   1-2023
# 6   2023      2       34   2-2023
# 7   2023      3        9   3-2023
# 8   2023      4        4   4-2023
# 9   2023      7       82   7-2023
# 10  2023      8        7   8-2023
# 11  2024      2       14   2-2024

# %%
temp1 = df['day'].value_counts()
temp1
# Out:
# day
# Thursday     96
# Monday       71
# Sunday       58
# Friday       38
# Tuesday      34
# Wednesday    16
# Saturday      2
# Name: count, dtype: int64

# %%
temp2 = df['month'].value_counts()
temp2
# Out:
# month
# 7     122
# 8      65
# 2      48
# 6      22
# 9      21
# 11     21
# 3       9
# 4       4
# 1       3
# Name: count, dtype: int64

# %%
temp = df.groupby(['year','month']).count()['Message'].reset_index()
temp
# Out:
#     year  month  Message
# 0   2022      6       22
# 1   2022      7       40
# 2   2022      8       58
# 3   2022      9       21
# 4   2022     11       21
# 5   2023      1        3
# 6   2023      2       34
# 7   2023      3        9
# 8   2023      4        4
# 9   2023      7       82
# 10  2023      8        7
# 11  2024      2       14
